# %%
import pandas as pd

sales = pd.read_csv('sales_data.csv')
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
YearSales = sales.drop(['Date', 'Day', 'Month', 'Customer_Age', 'Profit', 'Customer_Gender', 'Age_Group', 'Revenue', 'Cost', 'Unit_Price', 'Unit_Cost', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product'], axis=1)
YearSales
# Out:
#         Year  Order_Quantity
# 0       2013               8
# 1       2015               8
# 2       2014              23
# 3       2016              20
# 4       2014               4
# ...      ...             ...
# 113031  2016               3
# 113032  2014              22
# 113033  2016              22
# 113034  2014              24
# 113035  2016              23
#
# [113036 rows x 2 columns]

# %%
YearSales.keys()
# Out:
# Index(['Year', 'Order_Quantity'], dtype='object')

# %%
type(YearSales)
# Out:
# pandas.core.frame.DataFrame

# %%
U = YearSales.Year.unique()
U
# Out:
# array([2013, 2015, 2014, 2016, 2012, 2011], dtype=int64)

# %%
a = YearSales[YearSales.Year == 2013].sum()
a
# testing the df fetch
# Out:
# Year              49203759
# Order_Quantity      294787
# dtype: int64

# %%
w, h = 0, 0
Y = [[0 for a in range(w)] for b in range(h)]

# %%
for i in U:
    x = YearSales[YearSales.Year == i]
    Y.append([i, x['Order_Quantity'].sum()])
Y
# Out:
# [[2013, 294787],
#  [2015, 289517],
#  [2014, 379585],
#  [2016, 370813],
#  [2012, 5354],
#  [2011, 5260]]

# %%
for i in U:
    print(i, len(YearSales[YearSales.Year == i]))
# Out:
# 2013 24443
# 2015 24443
# 2014 29398
# 2016 29398
# 2012 2677
# 2011 2677

# %%
YearSales0 = pd.DataFrame(Y, columns = list('xy')).sort_values('x',ascending=True).rename(columns={'x':'Year','y':'Total Sales'})
YearSales0.plot.pie(y='Total Sales', labels = ['2011','2012','2013','2014','2015','2016'], title="Sales per Year", legend=True, autopct=lambda x : '{:.0f}'.format(x*YearSales0['Total Sales'].sort_values().sum()/100), explode=(0.15, 0.10, 0.05, 0.02, 0.01, 0), shadow=True, startangle=0, labeldistance = None, figsize=(7,7))
# Out:
# <Axes: title={'center': 'Sales per Year'}, ylabel='Total Sales'>
