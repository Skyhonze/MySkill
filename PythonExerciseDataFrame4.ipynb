# %%
import pandas as pd

sales = pd.read_csv('sales_data.csv')
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
ProductList = sales.drop(['Date', 'Day', 'Month', 'Customer_Age', 'Profit', 'Customer_Gender', 'Age_Group', 'Revenue', 'Cost', 'Unit_Price', 'Unit_Cost', 'Country', 'State'], axis=1)
ProductList
# Out:
#         Year Product_Category Sub_Category              Product  \
# 0       2013      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 1       2015      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 2       2014      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 3       2016      Accessories   Bike Racks  Hitch Rack - 4-Bike
# 4       2014      Accessories   Bike Racks  Hitch Rack - 4-Bike
# ...      ...              ...          ...                  ...
# 113031  2016         Clothing        Vests      Classic Vest, S
# 113032  2014         Clothing        Vests      Classic Vest, M
# 113033  2016         Clothing        Vests      Classic Vest, M
# 113034  2014         Clothing        Vests      Classic Vest, L
# 113035  2016         Clothing        Vests      Classic Vest, L
#
#         Order_Quantity
# 0                    8
# 1                    8
# 2                   23
# 3                   20
# 4                    4
# ...                ...
# 113031               3
# ...

# %%
# ProductList['Order_Quantity']==0
0 in ProductList.values
# Out:
# False

# %%
ProductList.drop(['Year', 'Order_Quantity'], axis=1)
P0 = ProductList.sort_values('Product', ascending = True)

# %%
type(P0)
# Out:
# pandas.core.frame.DataFrame

# %%
U = P0.Product.unique()
U
# Out:
# array(['AWC Logo Cap', 'All-Purpose Bike Stand', 'Bike Wash - Dissolver',
#        'Classic Vest, L', 'Classic Vest, M', 'Classic Vest, S',
#        'Fender Set - Mountain', 'HL Mountain Tire', 'HL Road Tire',
#        'Half-Finger Gloves, L', 'Half-Finger Gloves, M',
#        'Half-Finger Gloves, S', 'Hitch Rack - 4-Bike',
#        'Hydration Pack - 70 oz.', 'LL Mountain Tire', 'LL Road Tire',
#        'Long-Sleeve Logo Jersey, L', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, S', 'Long-Sleeve Logo Jersey, XL',
#        'ML Mountain Tire', 'ML Road Tire', 'Mountain Bottle Cage',
#        'Mountain Tire Tube', 'Mountain-100 Black, 38',
#        'Mountain-100 Black, 42', 'Mountain-100 Black, 44',
#        'Mountain-100 Black, 48', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 42', 'Mountain-100 Silver, 44',
#        'Mountain-100 Silver, 48', 'Mountain-200 Black, 38',
#        'Mountain-200 Black, 42', 'Mountain-200 Black, 46',
# ...

# %%
P0['Product_Split'] = P0['Product'].str.split(',')
ProductList0 = pd.DataFrame([P0['Product_Split'].str[0].unique()])
ProductList0 = ProductList0.set_index(0).T
ProductList0
# Out:
# 0                  AWC Logo Cap
# 1        All-Purpose Bike Stand
# 2         Bike Wash - Dissolver
# 3                  Classic Vest
# 4         Fender Set - Mountain
# 5              HL Mountain Tire
# 6                  HL Road Tire
# 7            Half-Finger Gloves
# 8           Hitch Rack - 4-Bike
# 9       Hydration Pack - 70 oz.
# 10             LL Mountain Tire
# 11                 LL Road Tire
# 12      Long-Sleeve Logo Jersey
# 13             ML Mountain Tire
# 14                 ML Road Tire
# 15         Mountain Bottle Cage
# 16           Mountain Tire Tube
# 17           Mountain-100 Black
# 18          Mountain-100 Silver
# 19           Mountain-200 Black
# 20          Mountain-200 Silver
# 21        Mountain-400-W Silver
# 22           Mountain-500 Black
# 23          Mountain-500 Silver
# 24          Patch Kit/8 Patches
# 25                 Racing Socks
# 26             Road Bottle Cage
# 27               Road Tire Tube
# 28                 Road-150 Red
# ...
